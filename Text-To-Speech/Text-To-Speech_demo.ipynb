# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os
import pandas as pd

pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files (x86)/Tesseract-OCR/tesseract.exe'

f = []
t = []
input_dir = r'C:/Users/rimib/Text-To-Speech/images/'

for root, dirs, filenames in os.walk(input_dir):
    for filename in filenames:
        try:
            print(filename)
            f.append(filename)
            img = Image.open(input_dir + filename)
            text = pytesseract.image_to_string(img, lang = 'eng')
            t.append(text)
            print(text)
        except:
            continue
df = pd.DataFrame(list(zip(f, t)),columns=['file_Name','Text'])
import pyttsx3 
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
for voice in voices:
    engine.setProperty('voice', voices[0].id) #'voices[1].id' will play female voice
rate = engine.getProperty('rate')
engine.setProperty('rate', 160)
engine.say(t)
engine.save_to_file(str(t), "demo.mp3")
engine.runAndWait()
engine.stop()

# from gtts import gTTS
# tts = gTTS(str(reader), lang='en')
# tts.save('audio1.mp3')
# Out:
# chapter4.png
# Chapter 4. Learning Experience and Relevance
#
# Graduate Rotational Internship Program (GRIP) Internship has provided me with
# unique skill set and the ability to perform within a community, build healthy
# connections with other candidates investing within the same domain as well as
# participating in other fields.
#
# In this program, I was asked to perform each task using tools like Tableau, Power Bl,
# SAS etc., which substantially opened up the possibility of
#
# 0 studying datasets,
# 0 observing patterns,
# 0 understanding metadata on a higher scale and upscaled creativity.
#
# This again in turn intrigued me as a candidate to work on each task scrupulously, for
# improving results presented in the form of 'Dashboards’ and 'Storyboard'.
# Uploading the screen-recorded videos on YouTube aided me to extricate from my
# comfort-zone and shed introversion.
#
# While we were also asked to provide feedback for fellow candidates, assessment of
# ...
